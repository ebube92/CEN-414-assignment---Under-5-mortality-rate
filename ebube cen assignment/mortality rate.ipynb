# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math
from statistics import mean, variance, stdev, mode, median
import pandas

# %%
data = pandas.read_csv("countrydata2.csv")
africa_array=["Algeria", "Angola", "Benin", "Botswana", "Burkina", "Burundi", "Cameroon", "Cape Verde", "Central African Republic", "Chad", "Comoros", "Congo", "Congo, Democratic Republic of", "Djibouti", "Egypt", "Equatorial Guinea", "Eritrea", "Ethiopia", "Gabon", "Gambia", "Ghana", "Guinea", "Guinea-Bissau", "Ivory Coast", "Kenya", "Lesotho", "Liberia", "Libya", "Madagascar", "Malawi", "Mali", "Mauritania", "Mauritius", "Morocco", "Mozambique", "Namibia", "Niger", "Nigeria", "Rwanda", "Sao Tome and Principe", "Senegal", "Seychelles", "Sierra Leone", "Somalia", "South Africa", "South Sudan", "Sudan", "Togo", "Tunisia", "Uganda", "Zambia", "Zimbabwe"]


data=data[data['Country'].isin(africa_array)]
data.set_index('Country', inplace=True)

data=data.sort_values('2010')



data
# Out:
#                   2010      2011      2012      2013      2014      2015  \
# Country
# Seychelles     12.8948   13.0118   13.1322   13.2627   13.3743   13.4838
# Tunisia        16.7622   16.4202   16.1535   15.9480   15.7744   15.6563
# Algeria        25.9057   25.2212   24.7540   24.4163   24.0427   23.7164
# Rwanda         59.2098   52.8085   47.8458   43.7067   40.4689   37.8476
# Senegal        61.4393   58.2120   55.3123   52.7730   50.4282   48.2313
# Uganda         70.1410   65.9353   61.2882   57.1673   53.5885   50.5364
# Zambia         73.5143   71.3085   69.3037   66.8692   64.2443   63.0506
# Togo           81.3593   78.9486   76.5957   74.2639   72.0190   69.8576
# Zimbabwe       81.3602   75.3798   67.9789   62.2508   58.9232   56.6957
# Nigeria       128.2918  126.0540  124.1134  122.4247  121.0499  119.6988
# Somalia       148.9593  144.4960  139.8575  135.1066  130.5621  126.1556
# Sierra Leone  153.3798  146.1214  139.3131  133.0101  130.8925  131.6601
#
#                   2016      2017      2018      2019
# Country
# Seychelles     13.5223   13.4445   13.2653   13.0222
# Tunisia        15.5938   15.5645   15.5024   15.3705
# Algeria        23.3106   22.8082   22.3297   21.8138
# Rwanda         35.7002   33.9566   32.5603   31.0584
# Senegal        46.2216   44.4051   42.7185   41.1247
# Uganda         47.4876   45.1010   42.9075   40.9553
# Zambia         61.1514   59.0842   58.1219   56.6104
# Togo           67.7335   65.5978   63.4494   61.3325
# Zimbabwe       54.2093   52.9993   50.7457   49.6199
# Nigeria       117.9791  115.9992  113.3390  110.3993
# Somalia       121.9089  117.8617  113.9514  110.6140
# Sierra Leone  116.6889  111.8053  107.1853  102.9312

# %%
for year in range(2010, 2020):
    data.plot.bar(y=str(year),figsize=(12,12),title=str(year))
    plt.figure(figsize=(50,50))
    #plt.title("a graph of adult literacy rate in africa")
    #plt.xlabel("country")
    #plt.ylabel("percentage")
    plt.show()

# %%
vertical=['2010','2011','2012','2013','2014','2015','2016','2017','2018','2019']

# %%
data[vertical].mean()
# Out:
# 2010    76.101458
# 2011    72.826442
# 2012    69.637358
# 2013    66.766608
# 2014    64.614000
# 2015    63.049183
# 2016    60.125600
# 2017    58.218950
# 2018    56.339700
# 2019    54.571017
# dtype: float64

# %%
data[vertical].std()
# Out:
# 2010    47.326438
# 2011    45.801604
# 2012    44.335658
# 2013    42.949722
# 2014    42.186799
# 2015    41.829652
# 2016    39.216739
# 2017    37.994488
# 2018    36.741740
# 2019    35.580594
# dtype: float64

# %%
data[vertical].var()
# Out:
# 2010    2239.791733
# 2011    2097.786936
# 2012    1965.650577
# 2013    1844.678654
# 2014    1779.726033
# 2015    1749.719795
# 2016    1537.952634
# 2017    1443.581095
# 2018    1349.955471
# 2019    1265.978642
# dtype: float64

# %%
data[vertical].mode
# Out:
# <bound method DataFrame.mode of                   2010      2011      2012      2013      2014      2015  \
# Country
# Seychelles     12.8948   13.0118   13.1322   13.2627   13.3743   13.4838
# Tunisia        16.7622   16.4202   16.1535   15.9480   15.7744   15.6563
# Algeria        25.9057   25.2212   24.7540   24.4163   24.0427   23.7164
# Rwanda         59.2098   52.8085   47.8458   43.7067   40.4689   37.8476
# Senegal        61.4393   58.2120   55.3123   52.7730   50.4282   48.2313
# Uganda         70.1410   65.9353   61.2882   57.1673   53.5885   50.5364
# Zambia         73.5143   71.3085   69.3037   66.8692   64.2443   63.0506
# Togo           81.3593   78.9486   76.5957   74.2639   72.0190   69.8576
# Zimbabwe       81.3602   75.3798   67.9789   62.2508   58.9232   56.6957
# Nigeria       128.2918  126.0540  124.1134  122.4247  121.0499  119.6988
# Somalia       148.9593  144.4960  139.8575  135.1066  130.5621  126.1556
# Sierra Leone  153.3798  146.1214  139.3131  133.0101  130.8925  131.6601
#
#                   2016      2017      2018      2019
# Country
# Seychelles     13.5223   13.4445   13.2653   13.0222
# Tunisia        15.5938   15.5645   15.5024   15.3705
# Algeria        23.3106   22.8082   22.3297   21.8138
# Rwanda         35.7002   33.9566   32.5603   31.0584
# Senegal        46.2216   44.4051   42.7185   41.1247
# Uganda         47.4876   45.1010   42.9075   40.9553
# Zambia         61.1514   59.0842   58.1219   56.6104
# Togo           67.7335   65.5978   63.4494   61.3325
# Zimbabwe       54.2093   52.9993   50.7457   49.6199
# Nigeria       117.9791  115.9992  113.3390  110.3993
# Somalia       121.9089  117.8617  113.9514  110.6140
# Sierra Leone  116.6889  111.8053  107.1853  102.9312  >

# %%
data[vertical].median
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.median of                   2010      2011      2012      2013      2014      2015  \
# Country
# Seychelles     12.8948   13.0118   13.1322   13.2627   13.3743   13.4838
# Tunisia        16.7622   16.4202   16.1535   15.9480   15.7744   15.6563
# Algeria        25.9057   25.2212   24.7540   24.4163   24.0427   23.7164
# Rwanda         59.2098   52.8085   47.8458   43.7067   40.4689   37.8476
# Senegal        61.4393   58.2120   55.3123   52.7730   50.4282   48.2313
# Uganda         70.1410   65.9353   61.2882   57.1673   53.5885   50.5364
# Zambia         73.5143   71.3085   69.3037   66.8692   64.2443   63.0506
# Togo           81.3593   78.9486   76.5957   74.2639   72.0190   69.8576
# Zimbabwe       81.3602   75.3798   67.9789   62.2508   58.9232   56.6957
# Nigeria       128.2918  126.0540  124.1134  122.4247  121.0499  119.6988
# Somalia       148.9593  144.4960  139.8575  135.1066  130.5621  126.1556
# Sierra Leone  153.3798  146.1214  139.3131  133.0101  130.8925  131.6601
#
#                   2016      2017      2018      2019
# Country
# Seychelles     13.5223   13.4445   13.2653   13.0222
# Tunisia        15.5938   15.5645   15.5024   15.3705
# Algeria        23.3106   22.8082   22.3297   21.8138
# Rwanda         35.7002   33.9566   32.5603   31.0584
# Senegal        46.2216   44.4051   42.7185   41.1247
# Uganda         47.4876   45.1010   42.9075   40.9553
# Zambia         61.1514   59.0842   58.1219   56.6104
# Togo           67.7335   65.5978   63.4494   61.3325
# Zimbabwe       54.2093   52.9993   50.7457   49.6199
# Nigeria       117.9791  115.9992  113.3390  110.3993
# Somalia       121.9089  117.8617  113.9514  110.6140
# Sierra Leone  116.6889  111.8053  107.1853  102.9312  >

# %%
data.groupby('Country').median().plot.bar(stacked=True)
plt.title('Median')
plt.show()

# %%
for year in range(2010,2020):
    data.plot.bar(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.hist(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.line(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))

# %%
for year in range(2010,2020):
    data.plot.kde(y=str(year),figsize=(11,11),title=str(year))
    plt.figure(figsize=(42,42))
